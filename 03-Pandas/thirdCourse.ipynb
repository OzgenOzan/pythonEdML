# %%
import numpy as np

# %%
import pandas as pd

# %%
myIndex = ["SSCB", "TC", "Cuba"]

# %%
myData = [1917, 1923, 1959]

# %%
mySer = pd.Series(data=myData, index=myIndex)

# %%
mySer
# Out:
# SSCB    1917
# TC      1923
# Cuba    1959
# dtype: int64

# %%
mySer[0]
# Out:
# 1917

# %%
mySer["SSCB"]
# Out:
# 1917

# %%
ages = {"eda": 25, "ozan": 28, "vera": 5}

# %%
pd.Series(ages)
# Out:
# eda     25
# ozan    28
# vera     5
# dtype: int64

# %% [markdown]
# ---

# %%
# Imaginary Sales Data for 1st and 2nd Quarters for Global Company
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China': 500, 'India': 210,'USA': 260}

# %%
sale_q1 = pd.Series(q1)

# %%
sale_q2 = pd.Series(q2)

# %%
sale_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
sale_q1.add(sale_q2, fill_value=0)
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %% [markdown]
# ---

# %%
np.random.seed(101)
myData = np.random.randint(0, 101, (4, 3))

# %%
myData
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myInd = ["NY", "TX", "AR", "CA"]

# %%
myCol = ["Jan", "Feb", "March"]

# %%
df = pd.DataFrame(myData, myInd, myCol)

# %%
df
# Out:
#     Jan  Feb  March
# NY   95   11     81
# TX   70   63     87
# AR   75    9     77
# CA   40    4     63

# %%
pwd
# Out:
# 'C:\\Users\\oozgen\\Desktop\\Udemy\\Python\\JosePortilla(ML)\\03-Pandas'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 84CF-D98A
#
#  Directory of C:\Users\oozgen\Desktop\Udemy\Python\JosePortilla(ML)\03-Pandas
#
# 21/10/2023  14:09    <DIR>          .
# 14/10/2023  15:09    <DIR>          ..
# 20/10/2023  21:20    <DIR>          .ipynb_checkpoints
# 14/10/2023  15:08    <DIR>          __pycache__
# 14/10/2023  15:08           565,390 00-Series.ipynb
# 14/10/2023  15:08           208,957 01-DataFrames.ipynb
# 14/10/2023  15:08           194,591 02-Conditional-Filtering.ipynb
# 14/10/2023  15:08           196,385 03-Useful-Methods.ipynb
# 14/10/2023  15:08            64,227 04-Missing-Data.ipynb
# 14/10/2023  15:08           219,627 05-Groupby-Operations-and-MultiIndex.ipynb
# 14/10/2023  15:08            62,966 06-Combining-DataFrames.ipynb
# 14/10/2023  15:08            32,972 07-Text-Methods.ipynb
# 14/10/2023  15:08            93,392 08-Time-Methods.ipynb
# 14/10/2023  15:08            65,234 09-Inputs-and-Outputs.ipynb
# ...

# %%
dfTest = pd.read_csv("tips.csv")

# %%
dfTest
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# ---

# %%
dfTest["tip_%"] = dfTest["tip"] / dfTest["total_bill"] * 100

# %%
dfTest
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID      tip_%
# ...

# %%
dfTest.drop("tip_%", axis=1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
dfTest
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID      tip_%
# ...

# %%
dfTest.drop("tip_%", axis=1, inplace=True)

# %%
dfTest
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
dfTest.reset_index(inplace=True)

# %%
dfTest.set_index("Payment ID", inplace=True)

# %%
dfTest.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
dfTest.iloc[0]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
dfTest.loc["Sun2959"]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %% [markdown]
# ---

# %%
dfTest.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
dfTest["total_bill"] > 40
# Out:
# Payment ID
# Sun2959    False
# Sun4608    False
# Sun4458    False
# Sun5260    False
# Sun2251    False
#            ...
# Sat2657    False
# Sat1766    False
# Sat3880    False
# Sat17      False
# Thur672    False
# Name: total_bill, Length: 244, dtype: bool

# %%
dfTest[dfTest["total_bill"] > 40]
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Fri9628          40.17   4.73    Male    Yes   Fri  Dinner     4
# Sat6240          44.30   2.50  Female    Yes   Sat  Dinner     3
# Thur3621         41.19   5.00    Male     No  Thur   Lunch     5
# Sun7518          48.17   5.00    Male     No   Sun  Dinner     6
# Sat1954          50.81  10.00    Male    Yes   Sat  Dinner     3
# Sun2337          45.35   3.50    Male    Yes   Sun  Dinner     3
# Sun5140          40.55   3.00    Male    Yes   Sun  Dinner     2
# Thur9313         43.11   5.00  Female    Yes  Thur   Lunch     4
# Sat4590          48.33   9.00    Male     No   Sat  Dinner     4
#
#             price_per_person       Payer Name         CC Number
# Payment ID
# Sat8139                12.07      Brian Ortiz  6596453823950595
# Fri9628                10.04    Aaron Bentley   180026611638690
# ...

# %%
dfTest[((dfTest["price_per_person"] > 10) & (dfTest["tip"] >= 5) & (dfTest["time"] == "Lunch")) | (dfTest["tip"] >= 10)]
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Thur8801         32.68   5.00    Male    Yes  Thur   Lunch     2
# Thur9003         24.71   5.85    Male     No  Thur   Lunch     2
# Sat1954          50.81  10.00    Male    Yes   Sat  Dinner     3
# Thur9313         43.11   5.00  Female    Yes  Thur   Lunch     4
#
#             price_per_person     Payer Name         CC Number
# Payment ID
# Thur8801               16.34  Daniel Murphy  5356177501009133
# Thur9003               12.36   Roger Taylor     4410248629955
# Sat1954                16.94  Gregory Clark  5473850968388236
# Thur9313               10.78    Brooke Soto  5544902205760175

# %%
prefDay = ["Fri", "Sat"]

# %%
dfTest[dfTest["day"].isin(prefDay)]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sat9213          20.65  3.35    Male     No  Sat  Dinner     3
# Sat1709          17.92  4.08    Male     No  Sat  Dinner     2
# Sat9618          20.29  2.75  Female     No  Sat  Dinner     2
# Sat9786          15.77  2.23  Female     No  Sat  Dinner     2
# Sat239           39.42  7.58    Male     No  Sat  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat9777          35.83  4.67  Female     No  Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No  Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75    Male     No  Sat  Dinner     2
#
#             price_per_person       Payer Name         CC Number
# Payment ID
# Sat9213                 6.88    Timothy Oneal  6568069240986485
# ...

# %% [markdown]
# ---

# %%
def last_four(num):
    return str(num)[-4:]

# %%
dfTest.head(5)["CC Number"].apply(last_four)
# Out:
# Payment ID
# Sun2959    3410
# Sun4608    9230
# Sun4458    1322
# Sun5260    5994
# Sun2251    7221
# Name: CC Number, dtype: object

# %%
dfTest["price_per_person"].mean()
# Out:
# 7.888196721311474

# %%
def pricey(price):
    if price <= 5:
        return "$"
    elif 5 < price <= 9:
        return "$$"
    else:
        return "$$$"

# %%
dfTest["price_per_person"].apply(pricey)
# Out:
# Payment ID
# Sun2959     $$
# Sun4608      $
# Sun4458     $$
# Sun5260    $$$
# Sun2251     $$
#           ...
# Sat2657    $$$
# Sat1766    $$$
# Sat3880    $$$
# Sat17       $$
# Thur672    $$$
# Name: price_per_person, Length: 244, dtype: object

# %%
dfTest["pricey"] = dfTest["price_per_person"].apply(pricey)

# %%
dfTest.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number pricey
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410     $$
# Sun4608                 3.45      Douglas Tucker  4478071379779230      $
# Sun4458                 7.00      Travis Walters  6011812112971322     $$
# Sun5260                11.84    Nathaniel Harris  4676137647685994    $$$
# Sun2251                 6.15        Tonya Carter  4832732618637221     $$

# %% [markdown]
# ---

# %%
dfTest["total_bill"].head().apply(lambda num: num *2)
# Out:
# Payment ID
# Sun2959    33.98
# Sun4608    20.68
# Sun4458    42.02
# Sun5260    47.36
# Sun2251    49.18
# Name: total_bill, dtype: float64

# %%
def tipper(total_bill, tip):
    if tip/total_bill >= 0.25:
        return "nice tipper"
    elif 0.1 <= tip/total_bill < 0.25:
        return "so so"
    else:
        return "tip's dead"

# %%
dfTest[["total_bill", "tip"]].apply(lambda arg: tipper(arg["total_bill"], arg["tip"]), axis=1)
# Out:
# Payment ID
# Sun2959    tip's dead
# Sun4608         so so
# Sun4458         so so
# Sun5260         so so
# Sun2251         so so
#               ...
# Sat2657         so so
# Sat1766    tip's dead
# Sat3880    tip's dead
# Sat17      tip's dead
# Thur672         so so
# Length: 244, dtype: object

# %%
dfTest["tipper"] = np.vectorize(tipper)(dfTest["total_bill"], dfTest["tip"])

# %%
dfTest
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number pricey  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410     $$
# ...

# %% [markdown]
# ---

# %%
dfMovie = pd.read_csv("movie_scores.csv")

# %%
dfMovie.isnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0       False      False  False  False            False             False
# 1        True       True   True   True             True              True
# 2       False      False  False  False             True              True
# 3       False      False  False  False            False             False
# 4       False      False  False  False            False             False

# %%
dfMovie[dfMovie["pre_movie_score"].notnull()]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
dfMovie.dropna(thresh=3)
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
dfMovie.dropna(axis=1, thresh=4).dropna(thresh=1)
# Out:
#   first_name last_name   age sex
# 0        Tom     Hanks  63.0   m
# 2       Hugh   Jackman  51.0   m
# 3      Oprah   Winfrey  66.0   f
# 4       Emma     Stone  31.0   f

# %%
dfMovie[["pre_movie_score","post_movie_score"]] = dfMovie[["pre_movie_score","post_movie_score"]].fillna(0)

# %%
# for column in ["pre_movie_score", "post_movie_score"]:
#     dfMovie[column].fillna(0, inplace=True)

# %%
dfMovie
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              0.0               0.0
# 2       Hugh   Jackman  51.0    m              0.0               0.0
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %% [markdown]
# ---

# %%
dfMpg = pd.read_csv("mpg.csv")

# %%
dfMpg.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
dfMpg.select_dtypes(include=np.number).groupby("model_year").mean()
# Out:
#                   mpg  cylinders  displacement       weight  acceleration  \
# model_year
# 70          17.689655   6.758621    281.413793  3372.793103     12.948276
# 71          21.250000   5.571429    209.750000  2995.428571     15.142857
# 72          18.714286   5.821429    218.375000  3237.714286     15.125000
# 73          17.100000   6.375000    256.875000  3419.025000     14.312500
# 74          22.703704   5.259259    171.740741  2877.925926     16.203704
# 75          20.266667   5.600000    205.533333  3176.800000     16.050000
# 76          21.573529   5.647059    197.794118  3078.735294     15.941176
# 77          23.375000   5.464286    191.392857  2997.357143     15.435714
# 78          24.061111   5.361111    177.805556  2861.805556     15.805556
# 79          25.093103   5.827586    206.689655  3055.344828     15.813793
# 80          33.696552   4.137931    115.827586  2436.655172     16.934483
# ...

# %%
dfMpg.select_dtypes(include=np.number).groupby(["model_year", "cylinders"]).mean()
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
# ...

# %%
dfMpg.select_dtypes(include=np.number).groupby(["model_year", "cylinders"]).mean()["mpg"]
# Out:
# model_year  cylinders
# 70          4            25.285714
#             6            20.500000
#             8            14.111111
# 71          4            27.461538
#             6            18.000000
#             8            13.428571
# 72          3            19.000000
#             4            23.428571
#             8            13.615385
# 73          3            18.000000
#             4            22.727273
#             6            19.000000
#             8            13.200000
# 74          4            27.800000
#             6            17.857143
#             8            14.200000
# 75          4            25.250000
#             6            17.583333
#             8            15.666667
# 76          4            26.766667
#             6            20.000000
#             8            14.666667
# 77          3            21.500000
#             4            29.107143
#             6            19.500000
#             8            16.000000
# ...

# %%
dfMpg.select_dtypes(include=np.number).groupby("model_year").describe().transpose()
# Out:
# model_year                   70           71           72           73  \
# mpg          count    29.000000    28.000000    28.000000    40.000000
#              mean     17.689655    21.250000    18.714286    17.100000
#              std       5.339231     6.591942     5.435529     4.700245
#              min       9.000000    12.000000    11.000000    11.000000
#              25%      14.000000    15.500000    13.750000    13.000000
#              50%      16.000000    19.000000    18.500000    16.000000
#              75%      22.000000    27.000000    23.000000    20.000000
#              max      27.000000    35.000000    28.000000    29.000000
# cylinders    count    29.000000    28.000000    28.000000    40.000000
#              mean      6.758621     5.571429     5.821429     6.375000
#              std       1.724926     1.665079     2.073708     1.807215
#              min       4.000000     4.000000     3.000000     3.000000
# ...

# %%
lvlTest = dfMpg.select_dtypes(include=np.number).groupby(["model_year", "cylinders"]).mean()

# %%
lvlTest.index.levels
# Out:
# FrozenList([[70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], [3, 4, 5, 6, 8]])

# %%
lvlTest.loc[[70, 82]]
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 82         4          32.071429    118.571429  2402.321429     16.703571
#            6          28.333333    225.000000  2931.666667     16.033333
#
#                         origin
# model_year cylinders
# 70         4          2.285714
#            6          1.000000
#            8          1.000000
# 82         4          1.714286
#            6          1.000000

# %%
lvlTest.loc[(70, 4)]
# Out:
# mpg               25.285714
# displacement     107.000000
# weight          2292.571429
# acceleration      16.000000
# origin             2.285714
# Name: (70, 4), dtype: float64

# %%
lvlTest.xs(key=82, level="model_year")
# Out:
#                  mpg  displacement       weight  acceleration    origin
# cylinders
# 4          32.071429    118.571429  2402.321429     16.703571  1.714286
# 6          28.333333    225.000000  2931.666667     16.033333  1.000000

# %%
dfMpg[dfMpg["cylinders"].isin([6, 8])].select_dtypes(include=np.number).groupby(["model_year", "cylinders"]).mean()
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         8          13.615385    344.846154  4228.384615     13.000000
# 73         6          19.000000    212.250000  2917.125000     15.687500
#            8          13.200000    365.250000  4279.050000     12.250000
# 74         6          17.857143    230.428571  3320.000000     16.857143
#            8          14.200000    315.200000  4438.400000     14.700000
# 75         6          17.583333    233.750000  3398.333333     17.708333
#            8          15.666667    330.500000  4108.833333     13.166667
# ...

# %%
dfMpg.select_dtypes(include=np.number).agg(["std", "mean"])["mpg"]
# Out:
# std      7.815984
# mean    23.514573
# Name: mpg, dtype: float64

# %%
dfMpg.select_dtypes(include=np.number).agg({"mpg":["std", "mean", "max", "min"], "weight":["min", "max", "mean"]})
# Out:
#             mpg       weight
# std    7.815984          NaN
# mean  23.514573  2970.424623
# max   46.600000  5140.000000
# min    9.000000  1613.000000
